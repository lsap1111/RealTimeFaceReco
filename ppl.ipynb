# %%
pip install opencv-python cvlib pygame
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'D:\\ana\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
pip uninstall opencv-python-headless

# %%
import sys
import os

src_path = r"C:\Users\hp\Downloads\project\Untitled Folder 3\src"
if src_path not in sys.path:
    sys.path.append(src_path)

from email_utils import send_email_with_attachment

# %%
import os

print("Current working directory:", os.getcwd())
print("Files and folders here:", os.listdir())

src_path = os.path.join(os.getcwd(), "src")
print("Does 'src' folder exist here?", os.path.exists(src_path))
print("Contents of 'src':", os.listdir(src_path) if os.path.exists(src_path) else "No src folder found")
# Out:
# Current working directory: c:\Users\hp\Downloads\project
# Files and folders here: ['.ipynb_checkpoints', 'access_log.csv', 'authorized_face1.jpg', 'authorized_faces', 'FaceDetectionSystem', 'logs', 'ppl.ipynb', 'unauthorized_attempts.txt', 'unauthorized_logs', 'unauthorized_snapshots', 'Untitled Folder', 'Untitled Folder 1', 'Untitled Folder 2', 'Untitled Folder 3', 'Untitled.ipynb']
# Does 'src' folder exist here? False
# Contents of 'src': No src folder found

# %%
import cv2
import cvlib
import pygame

print("✅ All libraries imported successfully!")
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.0)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ✅ All libraries imported successfully!

# %%
import cv2
import os

# Function to capture the authorized face
def capture_authorized_face(filename="authorized_face.jpg"):
    # Update the filename path to save in the specific folder
    folder_path = r"C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces"
    
    # Ensure the folder exists
    os.makedirs(folder_path, exist_ok=True)
    
    # Set the full path where the image will be saved
    file_path = os.path.join(folder_path, filename)
    
    cap = cv2.VideoCapture(0)
    print("📸 Press 's' to save the authorized face. Press 'q' to quit without saving.")

    while True:
        ret, frame = cap.read()
        if not ret:
            print("❌ Failed to access webcam.")
            break

        cv2.imshow("Capture Authorized Face", frame)

        key = cv2.waitKey(1) & 0xFF
        if key == ord('s'):
            cv2.imwrite(file_path, frame)
            print(f"✅ Authorized face saved as {file_path}")
            break
        elif key == ord('q'):
            print("❌ Capture cancelled.")
            break

    cap.release()
    cv2.destroyAllWindows()

# Run the function to take the photo
capture_authorized_face()
# Out:
# 📸 Press 's' to save the authorized face. Press 'q' to quit without saving.
# ✅ Authorized face saved as C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces\authorized_face.jpg

# %%
# !pip install dlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import cv2

# Load the pre-trained Haar Cascade model for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Start webcam
cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to grab frame")
        break

    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5)

    # Draw rectangle around detected faces
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (255, 0, 0), 2)

    # Show the frame with detected faces
    cv2.imshow("Real-Time Face Detection", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\hp\Downloads\project

# %% [markdown]
# capturing face

# %%
import cv2
import os

# Specify the folder where authorized faces will be saved
authorized_faces_folder = r"C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces"

# Ensure the folder exists, otherwise create it
if not os.path.exists(authorized_faces_folder):
    os.makedirs(authorized_faces_folder)

# Start webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("❌ Error: Could not open webcam.")
    exit()

print("📸 Press 's' to save the authorized face. Press 'q' to quit without saving.")

while True:
    ret, frame = cap.read()

    if not ret:
        print("❌ Failed to grab frame")
        break

    # Display the frame
    cv2.imshow("Capture Authorized Face", frame)

    # Wait for user input to save the face or quit
    key = cv2.waitKey(1) & 0xFF
    if key == ord('s'):
        # Save the frame as a new image in the authorized faces folder
        authorized_face_filename = os.path.join(authorized_faces_folder, "authorized_face.jpg")
        cv2.imwrite(authorized_face_filename, frame)
        print(f"✅ Authorized face saved as {authorized_face_filename}")
        break
    elif key == ord('q'):
        print("❌ Capture cancelled.")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 📸 Press 's' to save the authorized face. Press 'q' to quit without saving.
# ✅ Authorized face saved as C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces\authorized_face.jpg

# %%
import cv2
import os

# Path to the folder where authorized faces are saved
authorized_faces_folder = r"C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces"

# Load the Haar Cascade model for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Initialize face recognizer (LBPH Face Recognizer)
recognizer = cv2.face.LBPHFaceRecognizer_create()

# Load the authorized face for recognition
authorized_face_path = os.path.join(authorized_faces_folder, "authorized_face.jpg")
authorized_face_img = cv2.imread(authorized_face_path)

if authorized_face_img is None:
    print("❌ No authorized face found! Please capture an authorized face first.")
    exit()

# Convert the authorized face image to grayscale for face recognition
authorized_face_gray = cv2.cvtColor(authorized_face_img, cv2.COLOR_BGR2GRAY)

# Train the recognizer with the authorized face
recognizer.train([authorized_face_gray], np.array([0]))

# Start webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("❌ Error: Could not open webcam.")
    exit()

print("📸 Press 'q' to quit.")

while True:
    ret, frame = cap.read()

    if not ret:
        print("❌ Failed to grab frame")
        break

    # Convert the frame to grayscale for face detection
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5)

    # For each detected face, recognize and draw a rectangle around it
    for (x, y, w, h) in faces:
        detected_face = gray_frame[y:y + h, x:x + w]

        # Predict the label for the detected face (whether it matches the authorized face)
        label, confidence = recognizer.predict(detected_face)

        # If the confidence is below a threshold (i.e., recognized as the authorized face)
        if confidence < 100:
            cv2.putText(frame, f"Authorized - {round(100 - confidence)}%", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        else:
            cv2.putText(frame, "Unauthorized", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)

    # Show the frame with face detection and recognition result
    cv2.imshow("Real-Time Face Recognition", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 11
#       8 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#      10 # Initialize face recognizer (LBPH Face Recognizer)
# ---> 11 recognizer = cv2.face.LBPHFaceRecognizer_create()
#      13 # Load the authorized face for recognition
#      14 authorized_face_path = os.path.join(authorized_faces_folder, "authorized_face.jpg")
#
# AttributeError: module 'cv2.face' has no attribute 'LBPHFaceRecognizer_create'

# %% [markdown]
#  Train the Face Recognizer (LBPH)

# %%
import cv2
import os
import numpy as np

data_path = r"C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces"
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
recognizer = cv2.face.LBPHFaceRecognizer_create()

faces = []
labels = []
label_map = {}
current_id = 0

for person_name in os.listdir(data_path):
    person_path = os.path.join(data_path, person_name)
    if not os.path.isdir(person_path):
        continue

    label_map[current_id] = person_name

    for img_name in os.listdir(person_path):
        img_path = os.path.join(person_path, img_name)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        if img is None:
            continue

        faces.append(img)
        labels.append(current_id)
    current_id += 1

recognizer.train(faces, np.array(labels))
print("✅ Training completed with", len(label_map), "authorized users.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 7
#       5 data_path = r"C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces"
#       6 face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# ----> 7 recognizer = cv2.face.LBPHFaceRecognizer_create()
#       9 faces = []
#      10 labels = []
#
# AttributeError: module 'cv2.face' has no attribute 'LBPHFaceRecognizer_create'

# %%
# !pip uninstall opencv-python opencv-contrib-python -y

# !pip install opencv-contrib-python
# Out:
# Found existing installation: opencv-python 4.11.0.86
# Uninstalling opencv-python-4.11.0.86:
#   Successfully uninstalled opencv-python-4.11.0.86
# Found existing installation: opencv-contrib-python 4.11.0.86
# Uninstalling opencv-contrib-python-4.11.0.86:
#   Successfully uninstalled opencv-contrib-python-4.11.0.86
# WARNING: Failed to remove contents in a temporary directory 'C:\Users\hp\AppData\Local\Temp\pip-uninstall-qbsyy9za'.
# You can safely remove it manually.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached opencv_contrib_python-4.11.0.86-cp37-abi3-win_amd64.whl (46.2 MB)
# ...

# %%
import cv2
print(cv2.__file__)
print(cv2.__version__)
# Out:
# C:\Users\hp\AppData\Roaming\Python\Python310\site-packages\cv2\__init__.py
# 4.11.0

# %%
import cv2

print(cv2.__version__)  # OpenCV version

# Check if the face module exists and has the LBPH function
if hasattr(cv2, 'face'):
    print("cv2.face module found")
    print("Available functions in cv2.face:", dir(cv2.face))
else:
    print("cv2.face module NOT found")
# Out:
# 4.11.0
# cv2.face module found
# Available functions in cv2.face: ['__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__']

# %% [markdown]
# Email

# %%
import threading
import cv2
import os
import numpy as np
import datetime
import time


# Path to the folder where authorized faces are saved
authorized_faces_folder = r"C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces"

# Load Haar Cascade for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Initialize LBPH face recognizer
recognizer = cv2.face.LBPHFaceRecognizer_create()

# Threshold for confidence (lower means more confident)
CONFIDENCE_THRESHOLD = 100

# Map label IDs to user names (folder names)
def get_label_name_map(authorized_faces_folder):
    label_name_map = {}
    for idx, person_name in enumerate(os.listdir(authorized_faces_folder)):
        person_path = os.path.join(authorized_faces_folder, person_name)
        if os.path.isdir(person_path):
            label_name_map[idx] = person_name
    return label_name_map

label_name_map = get_label_name_map(authorized_faces_folder)

# Function to load faces and labels from authorized_faces_folder
def load_authorized_faces(authorized_faces_folder):
    images = []
    labels = []
    label = 0
    for person_name in os.listdir(authorized_faces_folder):
        person_folder = os.path.join(authorized_faces_folder, person_name)
        if not os.path.isdir(person_folder):
            continue
        for file in os.listdir(person_folder):
            if file.lower().endswith((".jpg", ".png")):
                image_path = os.path.join(person_folder, file)
                img = cv2.imread(image_path)
                if img is None:
                    print(f"Warning: Could not read image {image_path}")
                    continue
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
                faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
                for (x, y, w, h) in faces:
                    face = gray[y:y + h, x:x + w]
                    images.append(face)
                    labels.append(label)
        label += 1
    return images, labels

print("📂 Loading authorized faces...")
faces, labels = load_authorized_faces(authorized_faces_folder)

if len(faces) == 0:
    print("❌ No authorized faces found! Please add authorized faces in folders.")
    exit()

# Train recognizer
recognizer.train(faces, np.array(labels))

# Create folder for unauthorized snapshots if it doesn't exist
unauthorized_folder = os.path.join(os.getcwd(), "unauthorized_snapshots")
if not os.path.exists(unauthorized_folder):
    os.makedirs(unauthorized_folder)

# Email cooldown dictionary and period (in seconds)
email_cooldown = {}
COOLDOWN_PERIOD = 300  # 5 minutes


import smtplib
from email.message import EmailMessage





from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
import os

# Email details
sender_email = "sender@gmail.com"
receiver_email = "receiver@gmail.com"
password = "password"  # Use App Password for Gmail

# SMTP server details
smtp_server = "smtp.gmail.com"
smtp_port = 465

def send_email(subject, body, attachment_path=None):
    message = MIMEMultipart()
    message["From"] = sender_email
    message["To"] = receiver_email
    message["Subject"] = subject

    # Attach body
    message.attach(MIMEText(body, "plain"))

    # Attach image if provided
    if attachment_path and os.path.exists(attachment_path):
        with open(attachment_path, "rb") as attachment:
            part = MIMEBase("application", "octet-stream")
            part.set_payload(attachment.read())
            encoders.encode_base64(part)
            part.add_header(
                "Content-Disposition",
                f"attachment; filename={os.path.basename(attachment_path)}",
            )
            message.attach(part)

    # Send email
    context = ssl.create_default_context()
    with smtplib.SMTP_SSL(smtp_server, smtp_port, context=context) as server:
        server.login(sender_email, password)
        server.sendmail(sender_email, receiver_email, message.as_string())

    print("✅ Email sent with attachment!")




def send_email_threaded_with_cooldown(image_path):
    current_time = time.time()
    key = "unauthorized"  # Apply cooldown globally for all unauthorized faces
    last_sent_time = email_cooldown.get(key, 0)
    
    if current_time - last_sent_time > COOLDOWN_PERIOD:
        email_cooldown[key] = current_time
        thread = threading.Thread(target=send_email, args=(
            "🚨 Unauthorized Face Detected",
            "An unauthorized face was detected. See attached snapshot.",
            image_path
        ))
        thread.daemon = True
        thread.start()
    else:
        print(f"⚠️ Email cooldown active, skipping send.")


# Start webcam
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("❌ Error: Could not open webcam.")
    exit()

print("📸 Press 'q' to quit.")

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ Failed to grab frame")
        break

    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces_in_frame = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces_in_frame:
        detected_face = gray_frame[y:y + h, x:x + w]
        try:
            label, confidence = recognizer.predict(detected_face)
        except Exception as e:
            print(f"Recognition error: {e}")
            continue

        if confidence < CONFIDENCE_THRESHOLD:
            user_name = label_name_map.get(label, f"User {label}")
            cv2.putText(frame, f"{user_name} - {round(100 - confidence)}%", (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        else:
            # Unauthorized face detected - save snapshot
            cv2.putText(frame, "Unauthorized", (x, y - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)

            face_img = frame[y:y + h, x:x + w]
            timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
            file_path = os.path.join(unauthorized_folder, f"unauth_{timestamp}.jpg")
            cv2.imwrite(file_path, face_img)

            # Send email alert with cooldown
            send_email_threaded_with_cooldown(file_path)

    cv2.imshow("Real-Time Face Recognition", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 📂 Loading authorized faces...
# 📸 Press 'q' to quit.
# Exception in thread Thread-109 (send_email):
# Traceback (most recent call last):
#   File "D:\ana\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "C:\Users\hp\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#   File "D:\ana\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\hp\AppData\Local\Temp\ipykernel_18684\3741046544.py", line 121, in send_email
# NameError: name 'ssl' is not defined. Did you forget to import 'ssl'?
# ⚠️ Email cooldown active, skipping send.
# ⚠️ Email cooldown active, skipping send.
# ⚠️ Email cooldown active, skipping send.
# ⚠️ Email cooldown active, skipping send.
# ⚠️ Email cooldown active, skipping send.
# ⚠️ Email cooldown active, skipping send.
# ⚠️ Email cooldown active, skipping send.
# ⚠️ Email cooldown active, skipping send.
# ...

# %% [markdown]
# User Authorise

# %%
import cv2
import os
import numpy as np

# Path to the folder where authorized faces are saved
authorized_faces_folder = r"C:\Users\hp\Downloads\project\Untitled Folder 3\authorized_faces"

# Load the Haar Cascade model for face detection
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

Initialize the face recognizer (LBPH)
recognizer = cv2.face.LBPHFaceRecognizer_create()

# Function to load all authorized faces
def load_authorized_faces(authorized_faces_folder):
    images = []
    labels = []
    label = 0

    for root, dirs, files in os.walk(authorized_faces_folder):
        for file in files:
            if file.endswith(".jpg"):
                image_path = os.path.join(root, file)
                img = cv2.imread(image_path)
                gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

                # Detect face in the image
                faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

                for (x, y, w, h) in faces:
                    face = gray[y:y + h, x:x + w]
                    images.append(face)
                    labels.append(label)

                label += 1
    return images, labels

# Load authorized faces
print("📂 Loading authorized faces...")
faces, labels = load_authorized_faces(authorized_faces_folder)

if len(faces) == 0:
    print("❌ No authorized faces found! Please capture authorized faces first.")
    exit()

# Train the recognizer
recognizer.train(faces, np.array(labels))

# Start webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("❌ Error: Could not open webcam.")
    exit()

print("📸 Press 'q' to quit.")

while True:
    ret, frame = cap.read()

    if not ret:
        print("❌ Failed to grab frame")
        break

    # Convert the frame to grayscale for face detection
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces in the frame
    faces_in_frame = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces_in_frame:
        detected_face = gray_frame[y:y + h, x:x + w]

        # Predict the label for the detected face
        label, confidence = recognizer.predict(detected_face)

        # If the confidence is below a threshold (recognized face)
        if confidence < 100:
            user_name = f"User {label}"  # You can modify this to use actual user names if you want
            cv2.putText(frame, f"{user_name} - {round(100 - confidence)}%", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
        else:
            cv2.putText(frame, "Unauthorized", (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 0, 255), 2)

    # Show the frame with face detection and recognition result
    cv2.imshow("Real-Time Face Recognition", frame)

    # Press 'q' to quit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
#   Cell In[10], line 11
#     Initialize the face recognizer (LBPH)
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
#  Real-Time Face Recognition (Multiple Authorized People)

# %%
# import cv2
# import os
# import numpy as np

# # Paths
# project_dir = r"C:\Users\hp\Downloads\project\Untitled Folder 3"
# face_trained_path = os.path.join(project_dir, "models", "face_trained.yml")

# # Load recognizer and face detector
# recognizer = cv2.face.LBPHFaceRecognizer_create()

# # Check if the model exists before loading
# if os.path.exists(face_trained_path):
#     recognizer.read(face_trained_path)
# else:
#     print(f"❌ Model file not found at: {face_trained_path}")
#     exit()

# # Load face detector (Haar Cascade)
# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# # Load label map (from training step — should match the order used)
# label_map = {}
# authorized_dir = os.path.join(project_dir, "authorized_faces")

# # Ensure authorized_faces folder exists
# if not os.path.exists(authorized_dir):
#     print(f"❌ Authorized faces directory not found at: {authorized_dir}")
#     exit()

# for idx, name in enumerate(os.listdir(authorized_dir)):
#     label_map[idx] = name

# # Start webcam
# cap = cv2.VideoCapture(0)

# while True:
#     ret, frame = cap.read()
#     if not ret:
#         print("❌ Failed to grab frame")
#         break

#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#     faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

#     for (x, y, w, h) in faces:
#         face_roi = gray[y:y+h, x:x+w]
#         id_, confidence = recognizer.predict(face_roi)

#         if confidence < 60:
#             name = label_map.get(id_, "Unknown")
#             color = (0, 255, 0)  # Green for authorized
#             text = f"Authorized: {name}"
#         elif confidence < 85:
#             name = label_map.get(id_, "Unknown")
#             color = (0, 255, 255)  # Yellow for partially authorized
#             text = f"Partially Authorized: {name}"
#         else:
#             color = (0, 0, 255)  # Red for unauthorized
#             text = "Unauthorized"

#         cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
#         cv2.putText(frame, text, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

#     cv2.imshow("🔐 Face Recognition", frame)

#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break

# cap.release()
# cv2.destroyAllWindows()

# %% [markdown]
# Logging Unauthorized Attempts

# %% [markdown]
# Email Alert on Unauthorized Detection

# %%
# import smtplib
# import ssl
# from email.mime.text import MIMEText
# from email.mime.multipart import MIMEMultipart
# from email.mime.base import MIMEBase
# from email import encoders
# import os

# # Email details
# sender_email = "sender@gmail.com"
# receiver_email = "receiver@gmail.com"
# password = "pass"  # Use App Password for Gmail

# # SMTP server details
# smtp_server = "smtp.gmail.com"
# smtp_port = 465

# def send_email(subject, body, attachment_path=None):
#     message = MIMEMultipart()
#     message["From"] = sender_email
#     message["To"] = receiver_email
#     message["Subject"] = subject

#     # Attach body
#     message.attach(MIMEText(body, "plain"))

#     # Attach image if provided
#     if attachment_path and os.path.exists(attachment_path):
#         with open(attachment_path, "rb") as attachment:
#             part = MIMEBase("application", "octet-stream")
#             part.set_payload(attachment.read())
#             encoders.encode_base64(part)
#             part.add_header(
#                 "Content-Disposition",
#                 f"attachment; filename={os.path.basename(attachment_path)}",
#             )
#             message.attach(part)

#     # Send email
#     context = ssl.create_default_context()
#     with smtplib.SMTP_SSL(smtp_server, smtp_port, context=context) as server:
#         server.login(sender_email, password)
#         server.sendmail(sender_email, receiver_email, message.as_string())

#     print("✅ Email sent with attachment!")

# # Example call:
# # send_email("🚨 Unauthorized Face Detected", "An unknown person was detected!", "unauthorized.jpg")

# %% [markdown]
# : Real-Time Recognition with Logging + Email Alert

# %%
# !pip install opencv-python Pillow

# %%
# import cv2
# import os
# import numpy as np

# # Paths
# project_dir = r"C:\Users\hp\Downloads\project\Untitled Folder 3"
# dataset_dir = os.path.join(project_dir, "dataset")
# model_save_path = os.path.join(project_dir, "models", "face_trained.yml")
# label_map_save_path = os.path.join(project_dir, "models", "labels.npy")

# # Initialize face detector and recognizer
# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# recognizer = cv2.face.LBPHFaceRecognizer_create()

# faces = []
# labels = []
# current_id = 0
# label_map = {}

# # Check if dataset directory exists
# if not os.path.exists(dataset_dir):
#     raise FileNotFoundError(f"Dataset directory not found: {dataset_dir}")

# # Walk through dataset directory
# for root, dirs, files in os.walk(dataset_dir):
#     for file in files:
#         if file.lower().endswith((".jpg", ".png", ".jpeg")):
#             img_path = os.path.join(root, file)
#             img = cv2.imread(img_path)
#             gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

#             # Detect faces
#             faces_in_image = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)
#             for (x, y, w, h) in faces_in_image:
#                 face = gray[y:y + h, x:x + w]
#                 faces.append(face)
#                 labels.append(current_id)

#             label_map[current_id] = os.path.splitext(file)[0]  # Use filename without extension as label
#             current_id += 1

# # Check if we have training data
# if not faces:
#     raise ValueError("No faces found in dataset. Make sure the images contain detectable faces.")

# # Train the recognizer
# recognizer.train(faces, np.array(labels))

# # Save the trained model and label map
# recognizer.save(model_save_path)
# np.save(label_map_save_path, label_map)

# print(f"✅ Model trained and saved to: {model_save_path}")
# print(f"✅ Label map saved to: {label_map_save_path}")

# %%
# import os
# import shutil

# # Full base path where you want to organize everything
# base_path = r"C:\Users\hp\Downloads\project\Untitled Folder 3"

# # Step 1: Create base directory if it doesn't exist
# os.makedirs(base_path, exist_ok=True)

# # Step 2: Define subfolders
# folders = ["models", "dataset", "logs", "src", "assets"]

# # Step 3: Create subfolders inside the base path
# for folder in folders:
#     folder_path = os.path.join(base_path, folder)
#     os.makedirs(folder_path, exist_ok=True)
#     print(f"[INFO] Created folder: {folder_path}")

# # Step 4: Check and move model if needed
# model_filename = "face_trained.yml"
# existing_model_in_models = os.path.join(base_path, "models", model_filename)
# existing_model_in_base = os.path.join(base_path, model_filename)

# if os.path.exists(existing_model_in_models):
#     print(f"[INFO] Model already exists in: {existing_model_in_models}")
# elif os.path.exists(existing_model_in_base):
#     shutil.move(existing_model_in_base, existing_model_in_models)
#     print(f"[INFO] Moved model to: {existing_model_in_models}")
# else:
#     print(f"[WARN] Model file not found at: {existing_model_in_base} or in 'models' folder")

# %% [markdown]
# <!-- USING DEEPFACE -->

# %%
# !pip install deepface

# %%
# !pip install tf-keras

# %%
# Out:
# 📷 Starting face recognition. Press 'q' to quit.
# ✅ Email with image sent!

# %% [markdown]
# # XXXXX

# %%
# import os
# from src.trainer.recognizer_utils import train_and_save_model

# AUTHORIZED_DIR = "authorized_faces"
# MODEL_SAVE_PATH = "models/face_recognizer.yml"
# LOG_DIR = "logs"

# train_and_save_model(AUTHORIZED_DIR, MODEL_SAVE_PATH, LOG_DIR)

# %%
# import cv2
# import os
# import time
# from datetime import datetime
# from deepface import DeepFace
# from src.email_utils.mailer import send_alert_email
# from src.logger import setup_logger
# from src.utils.snapshot import save_snapshot
# from src.utils.unauthorized_logger import log_unauthorized

# AUTHORIZED_DIR = "authorized_faces"
# SNAPSHOT_DIR = "static/snapshots"
# LOG_PATH = "logs/face_detection.log"
# logger = setup_logger("FaceDetectionLogger", LOG_PATH)

# def verify_face(frame, authorized_faces):
#     for person in authorized_faces:
#         result = DeepFace.verify(frame, person["image"], enforce_detection=False)
#         if result['verified']:
#             return person["name"]
#     return None

# def load_authorized_faces():
#     faces = []
#     for name in os.listdir(AUTHORIZED_DIR):
#         person_dir = os.path.join(AUTHORIZED_DIR, name)
#         for img_name in os.listdir(person_dir):
#             img_path = os.path.join(person_dir, img_name)
#             faces.append({"name": name, "image": img_path})
#     return faces

# def run_face_detection():
#     authorized_faces = load_authorized_faces()
#     cap = cv2.VideoCapture(0)
#     last_sent_time = 0

#     while True:
#         ret, frame = cap.read()
#         if not ret:
#             break

#         try:
#             face_name = verify_face(frame, authorized_faces)
#             if face_name:
#                 label = f"Authorized: {face_name}"
#             else:
#                 label = "Unauthorized"
#                 now = time.time()
#                 if now - last_sent_time > 60:  # send email every 60 seconds max
#                     snapshot_path = save_snapshot(frame, SNAPSHOT_DIR)
#                     send_alert_email(snapshot_path)
#                     log_unauthorized("Unknown", snapshot_path)
#                     last_sent_time = now

#             cv2.putText(frame, label, (20, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0) if face_name else (0, 0, 255), 2)
#         except Exception as e:
#             logger.error(f"Error: {e}")

#         cv2.imshow("Face Recognition", frame)
#         if cv2.waitKey(1) & 0xFF == ord('q'):
#             break

#     cap.release()
#     cv2.destroyAllWindows()

# %%
# import sys
# sys.path.append(r"C:\Users\hp\Downloads\project\Untitled Folder 3")
# from src.logger import setup_logger
# import threading

# %%
# pip install opencv-contrib-python

# %%
# import cv2
# print(cv2.__version__)
# import cv2
# from cv2.face import LBPHFaceRecognizer_create
# import cv2
# print(cv2.__file__)  # Should point to the correct OpenCV location.

# %%
# import tkinter as tk
# from tkinter import ttk
# import cv2
# import os
# import time
# import logging
# from email.mime.text import MIMEText
# from email.mime.image import MIMEImage
# from email.mime.multipart import MIMEMultipart
# import smtplib
# import ssl
# import threading
# from PIL import Image, ImageTk

# # === Paths ===
# project_dir = r"C:\Users\hp\Downloads\project\Untitled Folder 3"
# model_path = os.path.join(project_dir, "models", "face_trained.yml")
# authorized_dir = os.path.join(project_dir, "authorized_faces")
# log_file_path = os.path.join(project_dir, "logs", "unauthorized.log")

# # === Logging ===
# logger = logging.getLogger()
# logger.setLevel(logging.INFO)
# if not logger.handlers:
#     handler = logging.FileHandler(log_file_path, encoding="utf-8")
#     handler.setFormatter(logging.Formatter('%(asctime)s - %(message)s'))
#     logger.addHandler(handler)

# # === Email Config ===
# sender_email = "sender@gmail.com"
# receiver_email = "receiver@gmail.com"
# password = "password"

# def send_email(subject, body, image_path):
#     try:
#         msg = MIMEMultipart()
#         msg["From"] = sender_email
#         msg["To"] = receiver_email
#         msg["Subject"] = subject
#         msg.attach(MIMEText(body, "plain"))

#         with open(image_path, "rb") as img:
#             msg.attach(MIMEImage(img.read(), name=os.path.basename(image_path)))

#         context = ssl.create_default_context()
#         with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
#             server.login(sender_email, password)
#             server.sendmail(sender_email, receiver_email, msg.as_string())

#         logger.info("✅ Email sent.")
#     except Exception as e:
#         logger.error(f"❌ Email failed: {e}")

# # === Face Recognizer ===
# recognizer = cv2.face.LBPHFaceRecognizer_create()
# recognizer.read(model_path)
# face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
# label_map = {idx: name for idx, name in enumerate(os.listdir(authorized_dir))}

# class FaceApp:
#     def __init__(self, root):
#         self.root = root
#         self.root.title("🔐 Face Detection")
#         self.root.geometry("800x600")

#         # Video feed label
#         self.video_label = tk.Label(self.root)
#         self.video_label.pack()

#         # Status label
#         self.status_var = tk.StringVar(value="🟢 Waiting for detection...")
#         self.status_label = ttk.Label(root, textvariable=self.status_var, font=("Arial", 14))
#         self.status_label.pack(pady=10)

#         # Email toggle
#         self.email_enabled = tk.BooleanVar(value=True)
#         self.email_toggle = ttk.Checkbutton(self.root, text="Enable Email Alerts", variable=self.email_enabled)
#         self.email_toggle.pack(pady=10)

#         # Start/Stop button
#         self.start_button = ttk.Button(self.root, text="Start Detection", command=self.toggle_detection)
#         self.start_button.pack(pady=10)

#         # Webcam capture
#         self.cap = cv2.VideoCapture(0)
#         self.running = False
#         self.last_email_time = 0
#         self.cooldown = 60  # seconds

#     def toggle_detection(self):
#         if self.running:
#             self.running = False
#             self.start_button.config(text="Start Detection")
#         else:
#             self.running = True
#             self.start_button.config(text="Stop Detection")
#             self.update_frame()

#     def update_frame(self):
#         if not self.running:
#             return

#         ret, frame = self.cap.read()
#         if not ret:
#             logger.error("❌ Failed to read frame.")
#             return

#         gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#         faces = face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5)

#         for (x, y, w, h) in faces:
#             roi = cv2.resize(gray[y:y+h, x:x+w], (200, 200))
#             id_, conf = recognizer.predict(roi)

#             if conf < 60:
#                 label = f"Authorized: {label_map.get(id_, 'Unknown')}"
#                 color = (0, 255, 0)
#             elif conf < 85:
#                 label = "Partially Authorized"
#                 color = (0, 255, 255)
#             else:
#                 label = "Unauthorized"
#                 color = (0, 0, 255)
#                 timestamp = time.time()
#                 if timestamp - self.last_email_time > self.cooldown and self.email_enabled.get():
#                     self.last_email_time = timestamp
#                     snapshot = frame.copy()
#                     snapshot_path = os.path.join(project_dir, "logs", f"unauth_{int(timestamp)}.jpg")
#                     cv2.imwrite(snapshot_path, snapshot)
#                     threading.Thread(
#                         target=send_email,
#                         args=("🚨 Alert", "Unauthorized face detected!", snapshot_path),
#                         daemon=True
#                     ).start()
#                     logger.warning(f"🚨 Unauthorized face logged at {snapshot_path}")

#             cv2.rectangle(frame, (x, y), (x+w, y+h), color, 2)
#             cv2.putText(frame, label, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, color, 2)

#         # Convert to ImageTk and update the Tkinter label
#         img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         img_pil = Image.fromarray(img_rgb)
#         img_tk = ImageTk.PhotoImage(image=img_pil)
#         self.video_label.imgtk = img_tk
#         self.video_label.configure(image=img_tk)

#         # Update the frame every 10ms
#         self.root.after(10, self.update_frame)

#     def close(self):
#         self.running = False
#         self.cap.release()
#         cv2.destroyAllWindows()
#         self.root.quit()

# # === Launch ===
# if __name__ == "__main__":
#     root = tk.Tk()
#     app = FaceApp(root)
#     root.protocol("WM_DELETE_WINDOW", app.close)
#     root.mainloop()
